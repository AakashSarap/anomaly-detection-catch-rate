# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# -- STEP 1: Generate synthetic T&S catch rate --

# Imagine this is 90 days of daily catch rate on YouTube
np.random.seed(42)
n_days = 90

# Normal operations: mean 82%, std dec 3%

# %%
# !git --version
# Out:
# git version 2.34.1
